# %% [markdown]
# ### Task 5: Sales prediction using Python
# ### Name of intern: Mahesh Shinde
# ### Batch: July P-2 OIBSIP

# %% [markdown]
# #### Step 1: Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# #### Step 2: Importing Dataset

# %%
data=pd.read_csv("C:/Users/Amlya Shinde/Downloads/sales_prediction.csv")
print(data)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# #### Step 3: Data Analysis

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.rename(columns={"Unnamed: 0":"Index"},inplace=True)
data
# Out:
#      Index     TV  Radio  Newspaper  Sales
# 0        1  230.1   37.8       69.2   22.1
# 1        2   44.5   39.3       45.1   10.4
# 2        3   17.2   45.9       69.3    9.3
# 3        4  151.5   41.3       58.5   18.5
# 4        5  180.8   10.8       58.4   12.9
# ..     ...    ...    ...        ...    ...
# 195    196   38.2    3.7       13.8    7.6
# 196    197   94.2    4.9        8.1    9.7
# 197    198  177.0    9.3        6.4   12.8
# 198    199  283.6   42.0       66.2   25.5
# 199    200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df=data.drop(columns="Index")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# #### Step 4: Data Visualization

# %%
sns.scatterplot( x="Sales", y="TV", data=data )
plt.title("SALES OF TV")
# Out:
# Text(0.5, 1.0, 'SALES OF TV')

# %%
sns.scatterplot( x="Sales", y="Radio", data=data )
plt.title("SALES OF RADIO")
# Out:
# Text(0.5, 1.0, 'SALES OF RADIO')

# %%
sns.scatterplot( x="Sales", y="Newspaper", data=data )
plt.title("SALES OF Newspaper")
# Out:
# Text(0.5, 1.0, 'SALES OF Newspaper')

# %%
sns.pairplot(df)

# %%
sns.lineplot(x="Sales",y="TV",data=df,color='black')
plt.show()

# %%
sns.lineplot(x="Sales",y="Radio",data=df,color='red')
plt.show()

# %%
sns.lineplot(x="Sales",y="Newspaper",data=df,color='blue')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap="summer")
# Out:
# <Axes: >

# %% [markdown]
# #### Step 5: s

# %%
x=np.array(df.drop(["Sales"],1))
y=np.array(df["Sales"])
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

data=pd.DataFrame(data={"Predicted Sales" : ypred.flatten()})
print(data)
# Out:
#     Predicted Sales
# 0         16.408024
# 1         20.889882
# 2         21.553843
# 3         10.608503
# 4         22.112373
# 5         13.105592
# 6         21.057192
# 7          7.461010
# 8         13.606346
# 9         15.155070
# 10         9.048320
# 11         6.653283
# 12        14.345545
# 13         8.903493
# 14         9.689590
# 15        12.164944
# 16         8.736284
# 17        16.265073
# 18        10.277596
# 19        18.831091
# 20        19.560367
# 21        13.251035
# 22        12.336207
# 23        21.306951
# 24         7.827403
# 25         5.809574
# 26        20.757532
# 27        11.981381
# 28         9.183496
# 29         8.506699
# 30        12.466468
# 31        10.003377
# 32        21.387671
# 33        12.249664
# 34        18.266615
# 35        20.137663
# 36        14.055140
# 37        20.854112
# 38        11.017444
# 39         4.568996
# C:\Users\Amlya Shinde\AppData\Local\Temp\ipykernel_25484\3732989664.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x=np.array(df.drop(["Sales"],1))

# %% [markdown]
# So this is how we can predict future sales of product using Python.
